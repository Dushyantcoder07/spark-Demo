# %%
from kafka import KafkaProducer
import json
import time
import random

producer = KafkaProducer(
    bootstrap_servers=["kafka:9092"],
    value_serializer=lambda x: json.dumps(x).encode("utf-8")
)

user_ids = [101, 102, 103, 104, 105]

print("Transaction Producer Started")

for i in range(100):

    tx_data = {
        "tx_id": i,
        "userId": random.choice(user_ids),
        "amount": round(random.uniform(1000, 20000), 2),
        "timestamp": time.time()
    }

    producer.send(
        "fraud-detection",
        value=tx_data
    )

    print("Sent:", tx_data)

    time.sleep(2)

producer.flush()
# Out:
# Transaction Producer Started
# Sent: {'tx_id': 0, 'userId': 104, 'amount': 13135.74, 'timestamp': 1781928202.1479282}
# Sent: {'tx_id': 1, 'userId': 101, 'amount': 16576.77, 'timestamp': 1781928204.3825972}
# Sent: {'tx_id': 2, 'userId': 102, 'amount': 10679.76, 'timestamp': 1781928206.3838205}
# Sent: {'tx_id': 3, 'userId': 102, 'amount': 6819.4, 'timestamp': 1781928208.385238}
# Sent: {'tx_id': 4, 'userId': 105, 'amount': 9106.1, 'timestamp': 1781928210.3860064}
# Sent: {'tx_id': 5, 'userId': 103, 'amount': 12635.98, 'timestamp': 1781928212.3868322}
# Sent: {'tx_id': 6, 'userId': 101, 'amount': 6755.61, 'timestamp': 1781928214.3882422}
# Sent: {'tx_id': 7, 'userId': 103, 'amount': 17524.55, 'timestamp': 1781928216.3889456}
# Sent: {'tx_id': 8, 'userId': 104, 'amount': 5883.25, 'timestamp': 1781928218.3901339}
# Sent: {'tx_id': 9, 'userId': 101, 'amount': 12774.92, 'timestamp': 1781928220.3913045}
# Sent: {'tx_id': 10, 'userId': 103, 'amount': 10679.55, 'timestamp': 1781928222.391786}
# Sent: {'tx_id': 11, 'userId': 102, 'amount': 17214.91, 'timestamp': 1781928224.3925207}
# Sent: {'tx_id': 12, 'userId': 101, 'amount': 2102.66, 'timestamp': 1781928226.393387}
# Sent: {'tx_id': 13, 'userId': 104, 'amount': 16847.0, 'timestamp': 1781928228.3938878}
# Sent: {'tx_id': 14, 'userId': 105, 'amount': 3137.85, 'timestamp': 1781928230.396661}
# Sent: {'tx_id': 15, 'userId': 103, 'amount': 10478.39, 'timestamp': 1781928232.3992465}
# Sent: {'tx_id': 16, 'userId': 103, 'amount': 13682.59, 'timestamp': 1781928234.4007478}
# Sent: {'tx_id': 17, 'userId': 101, 'amount': 8376.3, 'timestamp': 1781928236.402245}
# Sent: {'tx_id': 18, 'userId': 104, 'amount': 9316.85, 'timestamp': 1781928238.4039195}
# Sent: {'tx_id': 19, 'userId': 105, 'amount': 16304.4, 'timestamp': 1781928240.4044273}
# Sent: {'tx_id': 20, 'userId': 104, 'amount': 4184.69, 'timestamp': 1781928242.405776}
# Sent: {'tx_id': 21, 'userId': 104, 'amount': 12565.19, 'timestamp': 1781928244.4073646}
# Sent: {'tx_id': 22, 'userId': 101, 'amount': 19678.24, 'timestamp': 1781928246.4097676}
# Sent: {'tx_id': 23, 'userId': 102, 'amount': 11100.29, 'timestamp': 1781928248.4102364}
# Sent: {'tx_id': 24, 'userId': 101, 'amount': 2015.46, 'timestamp': 1781928250.411483}
# Sent: {'tx_id': 25, 'userId': 104, 'amount': 6139.97, 'timestamp': 1781928252.4121172}
# Sent: {'tx_id': 26, 'userId': 102, 'amount': 16034.5, 'timestamp': 1781928254.412601}
# Sent: {'tx_id': 27, 'userId': 102, 'amount': 11691.93, 'timestamp': 1781928256.4130821}
# Sent: {'tx_id': 28, 'userId': 104, 'amount': 12953.62, 'timestamp': 1781928258.4138255}
# Sent: {'tx_id': 29, 'userId': 101, 'amount': 7964.77, 'timestamp': 1781928260.4152431}
# Sent: {'tx_id': 30, 'userId': 104, 'amount': 3712.84, 'timestamp': 1781928262.4166725}
# Sent: {'tx_id': 31, 'userId': 103, 'amount': 8199.21, 'timestamp': 1781928264.4179902}
# Sent: {'tx_id': 32, 'userId': 101, 'amount': 16092.15, 'timestamp': 1781928266.4185092}
# Sent: {'tx_id': 33, 'userId': 103, 'amount': 14207.87, 'timestamp': 1781928268.4198563}
# Sent: {'tx_id': 34, 'userId': 103, 'amount': 11604.56, 'timestamp': 1781928270.4203794}
# Sent: {'tx_id': 35, 'userId': 101, 'amount': 10858.68, 'timestamp': 1781928272.4216259}
# Sent: {'tx_id': 36, 'userId': 102, 'amount': 3620.66, 'timestamp': 1781928274.4221516}
# Sent: {'tx_id': 37, 'userId': 101, 'amount': 10458.04, 'timestamp': 1781928276.4232965}
# Sent: {'tx_id': 38, 'userId': 101, 'amount': 12926.51, 'timestamp': 1781928278.4295864}
# Sent: {'tx_id': 39, 'userId': 104, 'amount': 10040.17, 'timestamp': 1781928280.430036}
# Sent: {'tx_id': 40, 'userId': 103, 'amount': 18308.33, 'timestamp': 1781928282.4312358}
# Sent: {'tx_id': 41, 'userId': 105, 'amount': 14762.42, 'timestamp': 1781928284.4317448}
# Sent: {'tx_id': 42, 'userId': 101, 'amount': 9510.33, 'timestamp': 1781928286.4324787}
# Sent: {'tx_id': 43, 'userId': 105, 'amount': 4928.69, 'timestamp': 1781928288.4329708}
# Sent: {'tx_id': 44, 'userId': 104, 'amount': 1265.15, 'timestamp': 1781928290.43419}
# Sent: {'tx_id': 45, 'userId': 102, 'amount': 13672.42, 'timestamp': 1781928292.4348946}
# Sent: {'tx_id': 46, 'userId': 102, 'amount': 7267.37, 'timestamp': 1781928294.4360247}
# Sent: {'tx_id': 47, 'userId': 104, 'amount': 6400.69, 'timestamp': 1781928296.4365819}
# Sent: {'tx_id': 48, 'userId': 104, 'amount': 16851.88, 'timestamp': 1781928298.4377754}
# Sent: {'tx_id': 49, 'userId': 101, 'amount': 5275.31, 'timestamp': 1781928300.4402475}
# Sent: {'tx_id': 50, 'userId': 103, 'amount': 8282.81, 'timestamp': 1781928302.440779}
# Sent: {'tx_id': 51, 'userId': 102, 'amount': 8561.03, 'timestamp': 1781928304.441457}
# Sent: {'tx_id': 52, 'userId': 103, 'amount': 15053.26, 'timestamp': 1781928306.4434087}
# Sent: {'tx_id': 53, 'userId': 102, 'amount': 2463.56, 'timestamp': 1781928308.443874}
# Sent: {'tx_id': 54, 'userId': 104, 'amount': 17487.5, 'timestamp': 1781928310.4449885}
# Sent: {'tx_id': 55, 'userId': 101, 'amount': 2994.76, 'timestamp': 1781928312.4455128}
# Sent: {'tx_id': 56, 'userId': 103, 'amount': 19560.47, 'timestamp': 1781928314.4460266}
# Sent: {'tx_id': 57, 'userId': 102, 'amount': 4943.49, 'timestamp': 1781928316.447243}
# Sent: {'tx_id': 58, 'userId': 102, 'amount': 3139.19, 'timestamp': 1781928318.4490757}
# Sent: {'tx_id': 59, 'userId': 105, 'amount': 8857.79, 'timestamp': 1781928320.4495804}
# Sent: {'tx_id': 60, 'userId': 102, 'amount': 10106.81, 'timestamp': 1781928322.4502065}
# Sent: {'tx_id': 61, 'userId': 105, 'amount': 9712.36, 'timestamp': 1781928324.4506762}
# Sent: {'tx_id': 62, 'userId': 103, 'amount': 15620.87, 'timestamp': 1781928326.451328}
# Sent: {'tx_id': 63, 'userId': 102, 'amount': 5825.94, 'timestamp': 1781928328.4526646}
# Sent: {'tx_id': 64, 'userId': 105, 'amount': 8149.1, 'timestamp': 1781928330.4531498}
# Sent: {'tx_id': 65, 'userId': 105, 'amount': 13931.36, 'timestamp': 1781928332.4547668}
# Sent: {'tx_id': 66, 'userId': 101, 'amount': 13600.77, 'timestamp': 1781928334.4553478}
# Sent: {'tx_id': 67, 'userId': 101, 'amount': 16238.77, 'timestamp': 1781928336.455857}
# Sent: {'tx_id': 68, 'userId': 101, 'amount': 18771.23, 'timestamp': 1781928338.4564972}
# Sent: {'tx_id': 69, 'userId': 103, 'amount': 1513.2, 'timestamp': 1781928340.4575708}
# Sent: {'tx_id': 70, 'userId': 101, 'amount': 19706.43, 'timestamp': 1781928342.4594855}
# Sent: {'tx_id': 71, 'userId': 105, 'amount': 13747.8, 'timestamp': 1781928344.4610608}
# Sent: {'tx_id': 72, 'userId': 102, 'amount': 9077.57, 'timestamp': 1781928346.4615479}
# Sent: {'tx_id': 73, 'userId': 101, 'amount': 12788.71, 'timestamp': 1781928348.4621646}
# Sent: {'tx_id': 74, 'userId': 104, 'amount': 15167.56, 'timestamp': 1781928350.4663768}
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[1], line 31
#      27     )
#      28
#      29     print("Sent:", tx_data)
#      30
# ---> 31     time.sleep(2)
#      32
#      33 producer.flush()
#
# KeyboardInterrupt:
