# %%
from kafka import KafkaProducer
import json
import time
import random

producer = KafkaProducer(
    bootstrap_servers=["kafka:9092"],
    value_serializer=lambda v: json.dumps(v).encode("utf-8")
)

user_ids = [101, 102, 103, 104, 105]

print("Starting Transaction Producer...")

for i in range(100):

    tx_data = {
        "tx_id": i,
        "userId": random.choice(user_ids),
        "amount": round(random.uniform(100, 15000), 2),
        "timestamp": time.time()
    }

    producer.send(
        "fraud-detection",
        value=tx_data
    )

    print("Sent:", tx_data)

    time.sleep(2)

producer.flush()
# Out:
# Starting Transaction Producer...
# Sent: {'tx_id': 0, 'userId': 105, 'amount': 10524.23, 'timestamp': 1781841116.9020832}
# Sent: {'tx_id': 1, 'userId': 101, 'amount': 10650.41, 'timestamp': 1781841119.1353865}
# Sent: {'tx_id': 2, 'userId': 105, 'amount': 6992.45, 'timestamp': 1781841121.1360404}
# Sent: {'tx_id': 3, 'userId': 102, 'amount': 11797.29, 'timestamp': 1781841123.1367757}
# Sent: {'tx_id': 4, 'userId': 103, 'amount': 10615.02, 'timestamp': 1781841125.1414874}
# Sent: {'tx_id': 5, 'userId': 105, 'amount': 7052.76, 'timestamp': 1781841127.1420128}
# Sent: {'tx_id': 6, 'userId': 105, 'amount': 11147.94, 'timestamp': 1781841129.1430185}
# Sent: {'tx_id': 7, 'userId': 105, 'amount': 4061.31, 'timestamp': 1781841131.14459}
# Sent: {'tx_id': 8, 'userId': 105, 'amount': 5205.18, 'timestamp': 1781841133.1487563}
# Sent: {'tx_id': 9, 'userId': 101, 'amount': 14313.9, 'timestamp': 1781841135.1492393}
# Sent: {'tx_id': 10, 'userId': 105, 'amount': 635.3, 'timestamp': 1781841137.149823}
# Sent: {'tx_id': 11, 'userId': 105, 'amount': 10406.66, 'timestamp': 1781841139.1502774}
# Sent: {'tx_id': 12, 'userId': 103, 'amount': 13767.54, 'timestamp': 1781841141.1508954}
# Sent: {'tx_id': 13, 'userId': 101, 'amount': 5154.99, 'timestamp': 1781841143.154683}
# Sent: {'tx_id': 14, 'userId': 101, 'amount': 14152.03, 'timestamp': 1781841145.1553118}
# Sent: {'tx_id': 15, 'userId': 104, 'amount': 4119.79, 'timestamp': 1781841147.1557188}
# Sent: {'tx_id': 16, 'userId': 105, 'amount': 13693.59, 'timestamp': 1781841149.1562119}
# Sent: {'tx_id': 17, 'userId': 101, 'amount': 368.78, 'timestamp': 1781841151.156655}
# Sent: {'tx_id': 18, 'userId': 101, 'amount': 11029.53, 'timestamp': 1781841153.1571467}
# Sent: {'tx_id': 19, 'userId': 102, 'amount': 5074.05, 'timestamp': 1781841155.1576178}
# Sent: {'tx_id': 20, 'userId': 101, 'amount': 14122.65, 'timestamp': 1781841157.1590898}
# Sent: {'tx_id': 21, 'userId': 101, 'amount': 8264.2, 'timestamp': 1781841159.1597283}
# Sent: {'tx_id': 22, 'userId': 101, 'amount': 6382.33, 'timestamp': 1781841161.1610441}
# Sent: {'tx_id': 23, 'userId': 105, 'amount': 11126.07, 'timestamp': 1781841163.1633396}
# Sent: {'tx_id': 24, 'userId': 102, 'amount': 9547.6, 'timestamp': 1781841165.1637864}
# Sent: {'tx_id': 25, 'userId': 104, 'amount': 13694.42, 'timestamp': 1781841167.1642468}
# Sent: {'tx_id': 26, 'userId': 103, 'amount': 3663.19, 'timestamp': 1781841169.1654987}
# Sent: {'tx_id': 27, 'userId': 102, 'amount': 330.93, 'timestamp': 1781841171.165913}
# Sent: {'tx_id': 28, 'userId': 104, 'amount': 14747.96, 'timestamp': 1781841173.1668675}
# Sent: {'tx_id': 29, 'userId': 103, 'amount': 1624.79, 'timestamp': 1781841175.1673617}
# Sent: {'tx_id': 30, 'userId': 101, 'amount': 3602.33, 'timestamp': 1781841177.1686413}
# Sent: {'tx_id': 31, 'userId': 103, 'amount': 8370.31, 'timestamp': 1781841179.1692522}
# Sent: {'tx_id': 32, 'userId': 102, 'amount': 11197.2, 'timestamp': 1781841181.1696994}
# Sent: {'tx_id': 33, 'userId': 104, 'amount': 4689.63, 'timestamp': 1781841183.170307}
# Sent: {'tx_id': 34, 'userId': 104, 'amount': 2603.63, 'timestamp': 1781841185.1724813}
# Sent: {'tx_id': 35, 'userId': 105, 'amount': 1421.63, 'timestamp': 1781841187.1736863}
# Sent: {'tx_id': 36, 'userId': 105, 'amount': 6323.01, 'timestamp': 1781841189.1743464}
# Sent: {'tx_id': 37, 'userId': 103, 'amount': 5287.87, 'timestamp': 1781841191.1810076}
# Sent: {'tx_id': 38, 'userId': 101, 'amount': 14815.86, 'timestamp': 1781841193.1912556}
# Sent: {'tx_id': 39, 'userId': 101, 'amount': 13968.17, 'timestamp': 1781841195.1923}
# Sent: {'tx_id': 40, 'userId': 101, 'amount': 14240.13, 'timestamp': 1781841197.1927662}
# Sent: {'tx_id': 41, 'userId': 102, 'amount': 1040.31, 'timestamp': 1781841199.1933877}
# Sent: {'tx_id': 42, 'userId': 103, 'amount': 12410.12, 'timestamp': 1781841201.1938176}
# Sent: {'tx_id': 43, 'userId': 102, 'amount': 8148.97, 'timestamp': 1781841203.1942954}
# Sent: {'tx_id': 44, 'userId': 102, 'amount': 7074.35, 'timestamp': 1781841205.1947544}
# Sent: {'tx_id': 45, 'userId': 104, 'amount': 943.46, 'timestamp': 1781841207.1952007}
# Sent: {'tx_id': 46, 'userId': 103, 'amount': 12961.35, 'timestamp': 1781841209.1964345}
# Sent: {'tx_id': 47, 'userId': 105, 'amount': 1329.37, 'timestamp': 1781841211.1977947}
# Sent: {'tx_id': 48, 'userId': 104, 'amount': 14864.71, 'timestamp': 1781841213.1982777}
# Sent: {'tx_id': 49, 'userId': 102, 'amount': 9724.2, 'timestamp': 1781841215.2031152}
# Sent: {'tx_id': 50, 'userId': 102, 'amount': 4876.37, 'timestamp': 1781841217.2035341}
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[1], line 31
#      27     )
#      28
#      29     print("Sent:", tx_data)
#      30
# ---> 31     time.sleep(2)
#      32
#      33 producer.flush()
#
# KeyboardInterrupt:
