# %%
from kafka import KafkaProducer
import json
import time
import random

producer = KafkaProducer(
    bootstrap_servers=["kafka:9092"],
    value_serializer=lambda v: json.dumps(v).encode("utf-8")
)

user_ids = [101, 102, 103, 104, 105]

print("Starting Transaction Producer...")

for i in range(100):

    tx_data = {
        "tx_id": i,
        "userId": random.choice(user_ids),
        "amount": round(random.uniform(100, 60000), 2),
        "timestamp": time.time()
    }

    producer.send(
        "fraud-detection",
        value=tx_data
    )

    print("Sent:", tx_data)

    time.sleep(2)

producer.flush()
# Out:
# Starting Transaction Producer...
# Sent: {'tx_id': 0, 'userId': 103, 'amount': 41405.48, 'timestamp': 1781845216.1117978}
# Sent: {'tx_id': 1, 'userId': 105, 'amount': 40424.16, 'timestamp': 1781845218.2099812}
# Sent: {'tx_id': 2, 'userId': 101, 'amount': 47238.27, 'timestamp': 1781845220.210717}
# Sent: {'tx_id': 3, 'userId': 104, 'amount': 59281.16, 'timestamp': 1781845222.2112257}
# Sent: {'tx_id': 4, 'userId': 105, 'amount': 33120.36, 'timestamp': 1781845224.2116601}
# Sent: {'tx_id': 5, 'userId': 105, 'amount': 36647.46, 'timestamp': 1781845226.2133174}
# Sent: {'tx_id': 6, 'userId': 102, 'amount': 14908.77, 'timestamp': 1781845228.2137687}
# Sent: {'tx_id': 7, 'userId': 101, 'amount': 912.23, 'timestamp': 1781845230.2153375}
# Sent: {'tx_id': 8, 'userId': 103, 'amount': 57607.67, 'timestamp': 1781845232.2164268}
# Sent: {'tx_id': 9, 'userId': 102, 'amount': 19074.18, 'timestamp': 1781845234.21762}
# Sent: {'tx_id': 10, 'userId': 104, 'amount': 52399.75, 'timestamp': 1781845236.2187214}
# Sent: {'tx_id': 11, 'userId': 102, 'amount': 24519.54, 'timestamp': 1781845238.21929}
# Sent: {'tx_id': 12, 'userId': 105, 'amount': 54964.16, 'timestamp': 1781845240.219847}
# Sent: {'tx_id': 13, 'userId': 105, 'amount': 57831.58, 'timestamp': 1781845242.2203786}
# Sent: {'tx_id': 14, 'userId': 104, 'amount': 38148.03, 'timestamp': 1781845244.222281}
# Sent: {'tx_id': 15, 'userId': 101, 'amount': 46826.58, 'timestamp': 1781845246.2236292}
# Sent: {'tx_id': 16, 'userId': 101, 'amount': 55162.07, 'timestamp': 1781845248.2241485}
# Sent: {'tx_id': 17, 'userId': 104, 'amount': 21532.35, 'timestamp': 1781845250.2248461}
# Sent: {'tx_id': 18, 'userId': 104, 'amount': 41555.75, 'timestamp': 1781845252.225389}
# Sent: {'tx_id': 19, 'userId': 101, 'amount': 24444.59, 'timestamp': 1781845254.2276661}
# Sent: {'tx_id': 20, 'userId': 103, 'amount': 46708.62, 'timestamp': 1781845256.2281935}
# Sent: {'tx_id': 21, 'userId': 105, 'amount': 19645.6, 'timestamp': 1781845258.2286575}
# Sent: {'tx_id': 22, 'userId': 105, 'amount': 57894.08, 'timestamp': 1781845260.2291486}
# Sent: {'tx_id': 23, 'userId': 104, 'amount': 14012.61, 'timestamp': 1781845262.229669}
# Sent: {'tx_id': 24, 'userId': 102, 'amount': 24901.03, 'timestamp': 1781845264.2310307}
# Sent: {'tx_id': 25, 'userId': 102, 'amount': 34797.89, 'timestamp': 1781845266.2330594}
# Sent: {'tx_id': 26, 'userId': 101, 'amount': 27257.59, 'timestamp': 1781845268.2335207}
# Sent: {'tx_id': 27, 'userId': 105, 'amount': 25636.49, 'timestamp': 1781845270.2339728}
# Sent: {'tx_id': 28, 'userId': 103, 'amount': 48708.02, 'timestamp': 1781845272.234458}
# Sent: {'tx_id': 29, 'userId': 102, 'amount': 40437.96, 'timestamp': 1781845274.2349346}
# Sent: {'tx_id': 30, 'userId': 105, 'amount': 13795.4, 'timestamp': 1781845276.2354336}
# Sent: {'tx_id': 31, 'userId': 103, 'amount': 45557.9, 'timestamp': 1781845278.2361104}
# Sent: {'tx_id': 32, 'userId': 105, 'amount': 45791.76, 'timestamp': 1781845280.23662}
# Sent: {'tx_id': 33, 'userId': 101, 'amount': 10475.93, 'timestamp': 1781845282.2371752}
# Sent: {'tx_id': 34, 'userId': 102, 'amount': 5788.4, 'timestamp': 1781845284.2376761}
# Sent: {'tx_id': 35, 'userId': 104, 'amount': 7295.11, 'timestamp': 1781845286.2387953}
# Sent: {'tx_id': 36, 'userId': 102, 'amount': 56594.74, 'timestamp': 1781845288.2393084}
# Sent: {'tx_id': 37, 'userId': 105, 'amount': 33044.13, 'timestamp': 1781845290.239781}
# Sent: {'tx_id': 38, 'userId': 102, 'amount': 33259.79, 'timestamp': 1781845292.2413177}
# Sent: {'tx_id': 39, 'userId': 103, 'amount': 16139.39, 'timestamp': 1781845294.2419426}
# Sent: {'tx_id': 40, 'userId': 103, 'amount': 33595.54, 'timestamp': 1781845296.2424836}
# Sent: {'tx_id': 41, 'userId': 102, 'amount': 9407.78, 'timestamp': 1781845298.2431493}
# Sent: {'tx_id': 42, 'userId': 103, 'amount': 32021.96, 'timestamp': 1781845300.2435935}
# Sent: {'tx_id': 43, 'userId': 104, 'amount': 15050.22, 'timestamp': 1781845302.2449577}
# Sent: {'tx_id': 44, 'userId': 105, 'amount': 38776.58, 'timestamp': 1781845304.2454307}
# Sent: {'tx_id': 45, 'userId': 103, 'amount': 47269.73, 'timestamp': 1781845306.2461135}
# Sent: {'tx_id': 46, 'userId': 102, 'amount': 56331.87, 'timestamp': 1781845308.247162}
# Sent: {'tx_id': 47, 'userId': 105, 'amount': 28639.05, 'timestamp': 1781845310.2476127}
# Sent: {'tx_id': 48, 'userId': 104, 'amount': 38625.13, 'timestamp': 1781845312.2487786}
# Sent: {'tx_id': 49, 'userId': 102, 'amount': 59251.22, 'timestamp': 1781845314.2502184}
# Sent: {'tx_id': 50, 'userId': 102, 'amount': 9985.52, 'timestamp': 1781845316.2516396}
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[2], line 31
#      27     )
#      28
#      29     print("Sent:", tx_data)
#      30
# ---> 31     time.sleep(2)
#      32
#      33 producer.flush()
#
# KeyboardInterrupt:
